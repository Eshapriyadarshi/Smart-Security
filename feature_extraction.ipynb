# %%
from os import listdir
from os.path import isdir, join
import librosa
import random
import numpy as np
import matplotlib.pyplot as plt
import python_speech_features
import tensorflow as tf

# %%
dataset_path = 'D:\data_speech_commands_v0.02'
for name in listdir(dataset_path):
    if isdir(join(dataset_path, name)):
        print(name)
# Out:
# backward
# bed
# bird
# cat
# dog
# down
# eight
# five
# follow
# forward
# four
# go
# happy
# house
# learn
# left
# marvin
# nine
# no
# off
# on
# one
# right
# seven
# sheila
# six
# stop
# three
# tree
# two
# up
# visual
# wow
# yes
# zero
# _background_noise_

# %%
all_targets = [name for name in listdir(dataset_path) if isdir(join(dataset_path, name))]
print(all_targets)
# Out:
# ['backward', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'follow', 'forward', 'four', 'go', 'happy', 'house', 'learn', 'left', 'marvin', 'nine', 'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree', 'two', 'up', 'visual', 'wow', 'yes', 'zero', '_background_noise_']

# %%
num_samples = 0
for target in all_targets:
    print(len(listdir(join(dataset_path, target))))
    num_samples += len(listdir(join(dataset_path, target)))
print('Total samples:', num_samples)
# Out:
# 1664
# 2014
# 2064
# 2031
# 2128
# 3917
# 3787
# 4052
# 1579
# 1557
# 3728
# 3880
# 2054
# 2113
# 1575
# 3801
# 2100
# 3934
# 3941
# 3745
# 3845
# 3890
# 3778
# 3998
# 2022
# 3860
# 3872
# 3727
# 1759
# 3880
# 3723
# 1592
# 2123
# 4044
# 4052
# 7
# Total samples: 105836

# %%
target_list = all_targets
feature_sets_file = 'all_targets_mfcc_sets.npz'
perc_keep_samples = 0.1 # 1.0 is keep all samples
val_ratio = 0.1
test_ratio = 0.1
sample_rate = 8000
num_mfcc = 16
len_mfcc = 16

# %%
filenames = []
y = []
for index, target in enumerate(target_list):
    print(join(dataset_path, target))
    filenames.append(listdir(join(dataset_path, target)))
    y.append(np.ones(len(filenames[index])) * index)
# Out:
# D:\data_speech_commands_v0.02\backward
# D:\data_speech_commands_v0.02\bed
# D:\data_speech_commands_v0.02\bird
# D:\data_speech_commands_v0.02\cat
# D:\data_speech_commands_v0.02\dog
# D:\data_speech_commands_v0.02\down
# D:\data_speech_commands_v0.02\eight
# D:\data_speech_commands_v0.02\five
# D:\data_speech_commands_v0.02\follow
# D:\data_speech_commands_v0.02\forward
# D:\data_speech_commands_v0.02\four
# D:\data_speech_commands_v0.02\go
# D:\data_speech_commands_v0.02\happy
# D:\data_speech_commands_v0.02\house
# D:\data_speech_commands_v0.02\learn
# D:\data_speech_commands_v0.02\left
# D:\data_speech_commands_v0.02\marvin
# D:\data_speech_commands_v0.02\nine
# D:\data_speech_commands_v0.02\no
# D:\data_speech_commands_v0.02\off
# D:\data_speech_commands_v0.02\on
# D:\data_speech_commands_v0.02\one
# D:\data_speech_commands_v0.02\right
# D:\data_speech_commands_v0.02\seven
# D:\data_speech_commands_v0.02\sheila
# D:\data_speech_commands_v0.02\six
# D:\data_speech_commands_v0.02\stop
# D:\data_speech_commands_v0.02\three
# D:\data_speech_commands_v0.02\tree
# D:\data_speech_commands_v0.02\two
# D:\data_speech_commands_v0.02\up
# D:\data_speech_commands_v0.02\visual
# D:\data_speech_commands_v0.02\wow
# D:\data_speech_commands_v0.02\yes
# D:\data_speech_commands_v0.02\zero
# D:\data_speech_commands_v0.02\_background_noise_

# %%
print(y)
for item in y:
    print(len(item))
# Out:
# [array([0., 0., 0., ..., 0., 0., 0.]), array([1., 1., 1., ..., 1., 1., 1.]), array([2., 2., 2., ..., 2., 2., 2.]), array([3., 3., 3., ..., 3., 3., 3.]), array([4., 4., 4., ..., 4., 4., 4.]), array([5., 5., 5., ..., 5., 5., 5.]), array([6., 6., 6., ..., 6., 6., 6.]), array([7., 7., 7., ..., 7., 7., 7.]), array([8., 8., 8., ..., 8., 8., 8.]), array([9., 9., 9., ..., 9., 9., 9.]), array([10., 10., 10., ..., 10., 10., 10.]), array([11., 11., 11., ..., 11., 11., 11.]), array([12., 12., 12., ..., 12., 12., 12.]), array([13., 13., 13., ..., 13., 13., 13.]), array([14., 14., 14., ..., 14., 14., 14.]), array([15., 15., 15., ..., 15., 15., 15.]), array([16., 16., 16., ..., 16., 16., 16.]), array([17., 17., 17., ..., 17., 17., 17.]), array([18., 18., 18., ..., 18., 18., 18.]), array([19., 19., 19., ..., 19., 19., 19.]), array([20., 20., 20., ..., 20., 20., 20.]), array([21., 21., 21., ..., 21., 21., 21.]), array([22., 22., 22., ..., 22., 22., 22.]), array([23., 23., 23., ..., 23., 23., 23.]), array([24., 24., 24., ..., 24., 24., 24.]), array([25., 25., 25., ..., 25., 25., 25.]), array([26., 26., 26., ..., 26., 26., 26.]), array([27., 27., 27., ..., 27., 27., 27.]), array([28., 28., 28., ..., 28., 28., 28.]), array([29., 29., 29., ..., 29., 29., 29.]), array([30., 30., 30., ..., 30., 30., 30.]), array([31., 31., 31., ..., 31., 31., 31.]), array([32., 32., 32., ..., 32., 32., 32.]), array([33., 33., 33., ..., 33., 33., 33.]), array([34., 34., 34., ..., 34., 34., 34.]), array([35., 35., 35., 35., 35., 35., 35.])]
# 1664
# 2014
# 2064
# 2031
# 2128
# 3917
# 3787
# 4052
# 1579
# 1557
# 3728
# 3880
# 2054
# 2113
# 1575
# 3801
# 2100
# 3934
# 3941
# 3745
# 3845
# 3890
# 3778
# 3998
# 2022
# 3860
# 3872
# 3727
# 1759
# 3880
# 3723
# 1592
# 2123
# 4044
# 4052
# 7

# %%
filenames = [item for sublist in filenames for item in sublist]
y = [item for sublist in y for item in sublist]

# %%
filenames_y = list(zip(filenames, y))
random.shuffle(filenames_y)
filenames, y = zip(*filenames_y)

# %%
print(len(filenames))
filenames = filenames[:int(len(filenames) * perc_keep_samples)]
print(len(filenames))
# Out:
# 105836
# 10583

# %%
val_set_size = int(len(filenames) * val_ratio)
test_set_size = int(len(filenames) * test_ratio)

# %%
filenames_val = filenames[:val_set_size]
filenames_test = filenames[val_set_size:(val_set_size + test_set_size)]
filenames_train = filenames[(val_set_size + test_set_size):]

# %%
y_orig_val = y[:val_set_size]
y_orig_test = y[val_set_size:(val_set_size + test_set_size)]
y_orig_train = y[(val_set_size + test_set_size):]

# %%
def calc_mfcc(path):
    
    # Load wavefile
    signal, fs = librosa.load(path, sr=sample_rate)
    
    # Create MFCCs from sound clip
    mfccs = python_speech_features.base.mfcc(signal, 
                                            samplerate=fs,
                                            winlen=0.256,
                                            winstep=0.050,
                                            numcep=num_mfcc,
                                            nfilt=26,
                                            nfft=2048,
                                            preemph=0.0,
                                            ceplifter=0,
                                            appendEnergy=False,
                                            winfunc=np.hanning)
    return mfccs.transpose()

# %%
prob_cnt = 0
x_test = []
y_test = []
for index, filename in enumerate(filenames_train):
    
    # Stop after 500
    if index >= 500:
        break
    
    # Create path from given filename and target item
    path = join(dataset_path, target_list[int(y_orig_train[index])], 
                filename)
    
    # Create MFCCs
    mfccs = calc_mfcc(path)
    
    if mfccs.shape[1] == len_mfcc:
        x_test.append(mfccs)
        y_test.append(y_orig_train[index])
    else:
        print('Dropped:', index, mfccs.shape)
        prob_cnt += 1
# Out:
# Dropped: 7 (16, 15)
# Dropped: 12 (16, 13)
# Dropped: 22 (16, 13)
# Dropped: 31 (16, 11)
# Dropped: 38 (16, 15)
# Dropped: 83 (16, 9)
# Dropped: 126 (16, 15)
# Dropped: 140 (16, 15)
# Dropped: 147 (16, 7)
# Dropped: 153 (16, 13)
# Dropped: 167 (16, 15)
# Dropped: 178 (16, 14)
# Dropped: 183 (16, 13)
# Dropped: 186 (16, 13)
# Dropped: 220 (16, 13)
# Dropped: 238 (16, 13)
# Dropped: 242 (16, 12)
# Dropped: 267 (16, 14)
# Dropped: 280 (16, 14)
# Dropped: 300 (16, 10)
# Dropped: 303 (16, 12)
# Dropped: 311 (16, 10)
# Dropped: 344 (16, 13)
# Dropped: 350 (16, 14)
# Dropped: 353 (16, 10)
# Dropped: 361 (16, 13)
# Dropped: 399 (16, 12)
# Dropped: 405 (16, 15)
# Dropped: 409 (16, 13)
# Dropped: 421 (16, 13)
# Dropped: 423 (16, 15)
# Dropped: 424 (16, 12)
# Dropped: 441 (16, 13)
# Dropped: 450 (16, 13)
# Dropped: 454 (16, 15)
# Dropped: 470 (16, 11)
# Dropped: 471 (16, 12)
# Dropped: 476 (16, 15)
# Dropped: 483 (16, 9)
# Dropped: 484 (16, 13)
# Dropped: 496 (16, 14)

# %%
print('% of problematic samples:', prob_cnt / 500)
# Out:
# % of problematic samples: 0.082

# %%
from playsound import playsound

idx = 13

# Create path from given filename and target item
path = join(dataset_path, target_list[int(y_orig_train[idx])], 
            filenames_train[idx])

# Create MFCCs
mfccs = calc_mfcc(path)
print("MFCCs:", mfccs)

# Plot MFCC
fig = plt.figure()
plt.imshow(mfccs, cmap='inferno', origin='lower')

# TEST: Play problem sounds
print(target_list[int(y_orig_train[idx])])
playsound(path)
# Out:
# MFCCs: [[-9.90671633e+01 -9.94904370e+01 -6.49707213e+01 -4.83434088e+01
#   -4.21266357e+01 -3.93318260e+01 -2.73306000e+01 -2.15501990e+01
#   -1.83544889e+01 -1.76974113e+01 -2.05168983e+01 -2.65155887e+01
#   -3.23111625e+01 -3.80961155e+01 -4.57868417e+01 -5.79396309e+01]
#  [ 2.76493412e-01  5.78018175e-01 -1.36887535e+00 -3.91215732e+00
#    1.01196879e+00  7.12639010e-01  7.00021872e-01  1.27037875e+00]
#  [-2.69584285e-01 -4.44706610e-01 -4.66323117e-01 -4.94695199e-01
#   -5.09606767e-01 -7.91761566e-02 -4.42445747e-02  2.77487417e-01
#   -1.91698328e-01 -1.03621170e+00 -9.99630684e-01 -4.11228846e-01
#    3.35374381e-02  4.53131051e-01  6.35972836e-01 -1.31971095e-01]
#  [-2.26892180e-01 -1.82461135e-02  6.39679985e-01 -3.42201026e-01
#   -5.22718221e-01 -1.87514014e+00 -2.03231855e+00 -2.29861858e+00
#   -2.02220019e+00 -1.46955726e+00 -1.31120863e+00 -1.55335780e+00
#   -1.29213778e+00 -5.19967433e-01  8.75539915e-02  4.02938927e-01]
#  [ 5.39530413e-02  6.93109463e-02  3.21331634e-01  1.20561251e+00
#    7.19106659e-01 -4.67723156e-01 -6.30388988e-01 -7.09595964e-01
#   -8.59665394e-01 -1.13607029e+00 -8.05090307e-01 -1.68230103e-01
#    2.09693120e-01  5.43041108e-02 -2.69397010e-01 -1.21539643e+00]
#  [ 1.82756123e-01  5.67803006e-02 -1.82956703e+00 -2.24078220e+00
#   -1.57150868e+00 -8.70921991e-01 -3.96065830e-01 -4.75195346e-01
#   -7.23949647e-01 -6.44739572e-01 -4.60215099e-01 -3.66424728e-01
#   -5.35970352e-01 -2.53491134e-01  1.64424351e-02 -1.08319187e-01]
#  [ 3.54018028e-01  2.64921400e-01  5.67467477e-01  3.19835587e-01
#   -2.82437766e-02 -3.36182200e-01 -1.48132672e-01 -2.76291389e-02
#    1.11079180e-01 -1.43409349e-01 -6.64217614e-01 -9.32510053e-01
#   -1.01329815e+00 -1.07502709e+00 -9.08807745e-01 -5.30253797e-01]]
# three

# %%
def extract_features(in_files, in_y):
    prob_cnt = 0
    out_x = []
    out_y = []
        
    for index, filename in enumerate(in_files):
    
        # Create path from given filename and target item
        path = join(dataset_path, target_list[int(in_y[index])], 
                    filename)
        
        # Check to make sure we're reading a .wav file
        if not path.endswith('.wav'):
            continue

        # Create MFCCs
        mfccs = calc_mfcc(path)

        # Only keep MFCCs with given length
        if mfccs.shape[1] == len_mfcc:
            out_x.append(mfccs)
            out_y.append(in_y[index])
        else:
            print('Dropped:', index, mfccs.shape)
            prob_cnt += 1
            
    return out_x, out_y, prob_cnt

# %%
with tf.device("/gpu:0"):    
    x_train, y_train, prob = extract_features(filenames_train, 
                                              y_orig_train)
    print('Removed percentage:', prob / len(y_orig_train))
    x_val, y_val, prob = extract_features(filenames_val, y_orig_val)
    print('Removed percentage:', prob / len(y_orig_val))
    x_test, y_test, prob = extract_features(filenames_test, y_orig_test)
    print('Removed percentage:', prob / len(y_orig_test))
# Out:
# Dropped: 7 (16, 15)
# Dropped: 12 (16, 13)
# Dropped: 22 (16, 13)
# Dropped: 31 (16, 11)
# Dropped: 38 (16, 15)
# Dropped: 83 (16, 9)
# Dropped: 126 (16, 15)
# Dropped: 140 (16, 15)
# Dropped: 147 (16, 7)
# Dropped: 153 (16, 13)
# Dropped: 167 (16, 15)
# Dropped: 178 (16, 14)
# Dropped: 183 (16, 13)
# Dropped: 186 (16, 13)
# Dropped: 138 (16, 14)
# Dropped: 139 (16, 14)
# Dropped: 143 (16, 11)
# Dropped: 149 (16, 15)
# Dropped: 181 (16, 11)
# Dropped: 191 (16, 11)
# Dropped: 196 (16, 7)
# Dropped: 208 (16, 14)
# Dropped: 228 (16, 6)
# Dropped: 245 (16, 15)
# Dropped: 271 (16, 11)
# Dropped: 273 (16, 11)
# Dropped: 276 (16, 12)
# Dropped: 280 (16, 13)
# Dropped: 290 (16, 10)
# Dropped: 308 (16, 14)
# Dropped: 311 (16, 13)
# Dropped: 314 (16, 11)
# Dropped: 320 (16, 11)
# Dropped: 331 (16, 15)
# Dropped: 339 (16, 14)
# Dropped: 340 (16, 13)
# Dropped: 362 (16, 12)
# Dropped: 375 (16, 14)
# Dropped: 379 (16, 11)
# Dropped: 385 (16, 11)
# Dropped: 414 (16, 13)
# Dropped: 419 (16, 12)
# Dropped: 437 (16, 8)
# Dropped: 464 (16, 15)
# Dropped: 469 (16, 9)
# Dropped: 481 (16, 11)
# Dropped: 501 (16, 14)
# Dropped: 512 (16, 12)
# Dropped: 522 (16, 13)
# Dropped: 529 (16, 8)
# Dropped: 537 (16, 11)
# Dropped: 540 (16, 14)
# Dropped: 555 (16, 11)
# Dropped: 556 (16, 11)
# Dropped: 558 (16, 12)
# Dropped: 562 (16, 15)
# Dropped: 568 (16, 5)
# Dropped: 571 (16, 13)
# Dropped: 595 (16, 14)
# Dropped: 623 (16, 15)
# Dropped: 634 (16, 15)
# Dropped: 637 (16, 13)
# Dropped: 638 (16, 11)
# Dropped: 649 (16, 11)
# Dropped: 652 (16, 15)
# Dropped: 656 (16, 10)
# Dropped: 658 (16, 14)
# Dropped: 662 (16, 9)
# Dropped: 674 (16, 11)
# Dropped: 704 (16, 12)
# Dropped: 724 (16, 12)
# Dropped: 748 (16, 10)
# Dropped: 768 (16, 12)
# Dropped: 773 (16, 11)
# Dropped: 774 (16, 3)
# Dropped: 776 (16, 5)
# Dropped: 797 (16, 12)
# Dropped: 811 (16, 12)
# Dropped: 812 (16, 13)
# Dropped: 823 (16, 10)
# Dropped: 834 (16, 15)
# Dropped: 845 (16, 13)
# Dropped: 853 (16, 12)
# Dropped: 867 (16, 13)
# Dropped: 899 (16, 12)
# Dropped: 901 (16, 12)
# Dropped: 907 (16, 15)
# Dropped: 911 (16, 14)
# Dropped: 927 (16, 15)
# Dropped: 939 (16, 9)
# Dropped: 949 (16, 12)
# Dropped: 965 (16, 11)
# Dropped: 968 (16, 15)
# Dropped: 981 (16, 15)
# Dropped: 986 (16, 15)
# Dropped: 1002 (16, 7)
# Dropped: 1006 (16, 12)
# Dropped: 1017 (16, 6)
# Dropped: 1022 (16, 10)
# Dropped: 1030 (16, 9)
# Dropped: 1034 (16, 15)
# Dropped: 1035 (16, 15)
# Dropped: 1052 (16, 15)
# Removed percentage: 0.09546313799621928

# %%
np.savez(feature_sets_file, 
         x_train=x_train, 
         y_train=y_train, 
         x_val=x_val, 
         y_val=y_val, 
         x_test=x_test, 
         y_test=y_test)

# %%
feature_sets = np.load(feature_sets_file)
feature_sets.files
# Out:
# ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']
